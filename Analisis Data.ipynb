# %% [markdown]
# <a href="https://colab.research.google.com/github/AryaPratamaPutra-10/AryaPratamaPutra-10/blob/main/Analisis%20Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analisis Harga Ikan Lele

# %% [markdown]
# 1. Import Library yang dipakai

# %%
# Install pustaka yang diperlukan (jika belum terinstal)
# !pip install numpy pandas matplotlib statsmodels

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score

from statsmodels.tsa.arima.model import ARIMA

# %% [markdown]
# 2. Import File Data Set

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-c80c6d7d-232d-4a54-8ad7-a825c44ea9b7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c80c6d7d-232d-4a54-8ad7-a825c44ea9b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Tampilin Data

# %%
df = pd.read_csv('/content/Harga_Lele.csv', sep=';')
df.head()
# Out:
#   Provinsi   Kabupaten/Kota  Tahun  Volume Produksi  Nilai Produksi
# 0     ACEH       ACEH BARAT   2019           247150    3.707250e+09
# 1     ACEH  ACEH BARAT DAYA   2019            50900    1.527000e+09
# 2     ACEH       ACEH BESAR   2019          1250560    1.970712e+10
# 3     ACEH        ACEH JAYA   2019           900000    1.800000e+10
# 4     ACEH     ACEH SELATAN   2019            39367    1.181010e+09

# %% [markdown]
# 3. Memisahkan Fitur dan Target

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer # Import ColumnTransformer

# Membaca file CSV ke dalam DataFrame
Harga_Lele = pd.read_csv('/content/Harga_Lele.csv', sep=';')

# Assign Harga_Lele to data
data = Harga_Lele

# cetak nama
print(data.columns)

# Fitur (tahun)
X = data[['Tahun', 'Provinsi']]

# Target: volume_produksi dan nilai_produksi
y_volume = data['Volume Produksi']
y_nilai = data['Nilai Produksi']

# OneHotEncoding untuk kolom 'daerah'
preprocessor = ColumnTransformer(transformers=[('Provinsi', OneHotEncoder(), ['Provinsi'])], remainder='passthrough')

# Transformasi X
X_transformed = preprocessor.fit_transform(X)
# Out:
# Index(['Provinsi', 'Kabupaten/Kota', 'Tahun', 'Volume Produksi',
#        'Nilai Produksi'],
#       dtype='object')

# %%
print(X.head()) # fitur
print(y.head()) # target
print(y.head()) # target
# Out:
#    Tahun Provinsi
# 0   2019     ACEH
# 1   2019     ACEH
# 2   2019     ACEH
# 3   2019     ACEH
# 4   2019     ACEH
# 0     247150
# 1      50900
# 2    1250560
# 3     900000
# 4      39367
# Name: Volume Produksi, dtype: int64
# 0     247150
# 1      50900
# 2    1250560
# 3     900000
# 4      39367
# Name: Volume Produksi, dtype: int64

# %% [markdown]
# 3 split dataset into training

# %%
# Membagi dataset menjadi 80% data latih dan 20% data uji
from sklearn.model_selection import train_test_split # import the necessary module
from sklearn.linear_model import LinearRegression


# Membagi data untuk model prediksi volume_produksi
X_train, X_test, y_volume_train, y_volume_test = train_test_split(X_transformed, y_volume, test_size=0.2, random_state=42)


# Membagi data untuk model prediksi nilai_produksi
_, _, y_nilai_train, y_nilai_test = train_test_split(X_transformed, y_nilai, test_size=0.2, random_state=42)

# %% [markdown]
# 4 create a Linear Regression model and train

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


# Mengubah 'y_nilai_train' ke numerik, menangani koma dan error
#y_nilai_train = y_nilai_train.str.replace(',', '.', regex=False).astype(float, errors='raise')
#Mengubah 'y_nilai_test' ke numerik, menangani koma dan error
# y_nilai_test = y_nilai_test.str.replace(',', '.', regex=False).astype(float, errors='raise')

# Lanjutkan untuk melatih model

# Model regresi linear untuk volume_produksi
#model_volume = LinearRegression()
#model_volume.fit(X_train, y_volume_train)

# Model regresi linear untuk nilai_produksi
#model_nilai = LinearRegression()
#model_nilai.fit(X_train, y_nilai_train)

# Check data types before applying any transformations
print(y_nilai_train.dtype)
print(y_nilai_test.dtype)

# If y_nilai_train or y_nilai_test are NOT of object dtype:
if y_nilai_train.dtype != object:
    # Convert them to strings first if necessary for replacing commas
    y_nilai_train = y_nilai_train.astype(str).str.replace(',', '.', regex=False).astype(float, errors='raise')
else:
    # If already object dtype, proceed with the replace
    y_nilai_train = y_nilai_train.str.replace(',', '.', regex=False).astype(float, errors='raise')

# Similarly for y_nilai_test
if y_nilai_test.dtype != object:
    y_nilai_test = y_nilai_test.astype(str).str.replace(',', '.', regex=False).astype(float, errors='raise')
else:
    y_nilai_test = y_nilai_test.str.replace(',', '.', regex=False).astype(float, errors='raise')


# Continue training the models
# Model regresi linear untuk volume_produksi
model_volume = LinearRegression()
model_volume.fit(X_train, y_volume_train)

# Model regresi linear untuk nilai_produksi
model_nilai = LinearRegression()
model_nilai.fit(X_train, y_nilai_train)

# ... (sisa kode Anda) ...
# Out:
# float64
# float64
# LinearRegression()

# %% [markdown]
# Ridge Regression model and train

# %%
ridge_model = Ridge(alpha=1.0)
ridge_model.fit(X_train, y_volume_train)
# Out:
# Ridge()

# %% [markdown]
# Lasso Regression model and train

# %%
lasso_model = Lasso(alpha=1.0)
lasso_model.fit(X_train, y_volume_train)
y_pred_lasso = lasso_model.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:658: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.5204357890230204e+16, tolerance: 9092834931809.31
#   model = cd_fast.sparse_enet_coordinate_descent(

# %% [markdown]
#  Create an Elastic Net Regression Model

# %%
elastic_net_model = ElasticNet(alpha=1.0, l1_ratio=0.5)
elastic_net_model.fit(X_train, y_train) # melatih model dengan data latih
y_pred_en = elastic_net_model.predict(X_test) # Melakukan prediksi pada data uji

# %% [markdown]
# Evaluasi the models

# %% [markdown]
# Membangun dan melatih model ARIMA untuk nilai produksi

# %%
# Inisialisasi model ARIMA untuk nilai_produksi
model_nilai = ARIMA(y_nilai, order=(1, 1, 1))  # (p, d, q) adalah parameter ARIMA
results_nilai = model_nilai.fit()

# Tampilkan ringkasan model
print(results_nilai.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:         Nilai Produksi   No. Observations:                 2222
# Model:                 ARIMA(1, 1, 1)   Log Likelihood              -60198.286
# Date:                Thu, 24 Oct 2024   AIC                         120402.571
# Time:                        15:02:07   BIC                         120419.688
# Sample:                             0   HQIC                        120408.823
#                                - 2222
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0080      0.027      0.299      0.765      -0.044       0.060
# ma.L1         -0.9620      0.004   -271.276      0.000      -0.969      -0.955
# sigma2      2.359e+22   8.07e-26   2.92e+47      0.000    2.36e+22    2.36e+22
# ...

# %% [markdown]
# membangun dan melatih model ARIMA untuk volume produksi

# %%
model_volume = ARIMA(y_volume, order=(1, 1, 1))  # (p, d, q) adalah parameter ARIMA
results_volume = model_volume.fit()

# Tampilkan ringkasan model
print(results_volume.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:        Volume Produksi   No. Observations:                 2222
# Model:                 ARIMA(1, 1, 1)   Log Likelihood              -38272.440
# Date:                Thu, 24 Oct 2024   AIC                          76550.881
# Time:                        12:34:43   BIC                          76567.998
# Sample:                             0   HQIC                         76557.133
#                                - 2222
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0211      0.024      0.895      0.371      -0.025       0.067
# ma.L1         -0.9590      0.004   -254.027      0.000      -0.966      -0.952
# sigma2      6.244e+13   3.26e-17   1.91e+30      0.000    6.24e+13    6.24e+13
# ...

# %%
# Prediksi volume_produksi
y_volume_pred = model_volume.predict(X_test)
print("MSE untuk volume_produksi:", mean_squared_error(y_volume_test, y_volume_pred))
print("R^2 untuk volume_produksi:", r2_score(y_volume_test, y_volume_pred))

# Prediksi nilai_produksi
y_nilai_pred = model_nilai.predict(X_test)
print("MSE untuk nilai_produksi:", mean_squared_error(y_nilai_test, y_nilai_pred))
print("R^2 untuk nilai_produksi:", r2_score(y_nilai_test, y_nilai_pred))
# Out:
# MSE untuk volume_produksi: 63436922764785.06
# R^2 untuk volume_produksi: 0.1089346167021874
# MSE untuk nilai_produksi: 3.156339222137906e+22
# R^2 untuk nilai_produksi: 0.0840942342191886

# %% [markdown]
# Evaluasi Model

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# Assuming 'categorical_features' is a list of your categorical column names
categorical_features = ['Provinsi'] # Replace with your actual categorical features
numerical_features = ['Tahun'] # Replace with your actual numerical features

preprocessor = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', numerical_features),
        ('cat', OneHotEncoder(sparse_output=False, handle_unknown='ignore'), categorical_features),
    ])

# Fit the preprocessor on your training data:
# preprocessor.fit(X_train)

# ... (rest of your code)

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# ... (Kode Anda yang lain) ...

# Asumsikan 'categorical_features' adalah daftar nama kolom kategorikal Anda
categorical_features = ['Provinsi'] # Ganti dengan fitur kategorikal Anda yang sebenarnya
numerical_features = ['Tahun'] # Ganti dengan fitur numerik Anda yang sebenarnya

preprocessor = ColumnTransformer(
    transformers=[
        ('num', 'passthrough', numerical_features),
        ('cat', OneHotEncoder(sparse_output=False, handle_unknown='ignore'), categorical_features),
    ])

# Latih preprocessor pada data pelatihan Anda:
preprocessor.fit(X_train)
# Baris ini sebelumnya dikomentari - sekarang aktif

# ... (Sisa kode Anda) ...

# Input baru
tahun_baru = [[2025, 'Aceh']]

# Ubah tahun_baru menjadi pandas DataFrame
tahun_baru_df = pd.DataFrame(tahun_baru, columns=['Tahun', 'Provinsi'])  # Asumsikan 'tahun' dan 'kota' adalah nama kolom Anda

# Transformasi input baru menggunakan DataFrame
tahun_baru_transformed = preprocessor.transform(tahun_baru_df)

# ... (Sisa kode prediksi Anda) ...
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_indexing.py in _get_column_indices(X, key)
#     337         try:
# --> 338             all_columns = X.columns
#     339         except AttributeError:
#
# AttributeError: 'csr_matrix' object has no attribute 'columns'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-d6ea72813af6> in <cell line: 21>()
#      19
#      20 # Latih preprocessor pada data pelatihan Anda:
# ---> 21 preprocessor.fit(X_train)
#      22 # Baris ini sebelumnya dikomentari - sekarang aktif
#      23
#
# /usr/local/lib/python3.10/dist-packages/sklearn/compose/_column_transformer.py in fit(self, X, y, **params)
# ...
